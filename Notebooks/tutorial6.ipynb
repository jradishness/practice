# %%
name = input("Hi, what's your name?")
print("Welcome to the game, " + name, ".")
# Out:
# Hi, what's your name?jared
# Welcome to the game, jared .

# %%
import nltk
from nltk import word_tokenize # Can't get this to work with terminal

# %%
whos
# Out:
# Variable        Type        Data/Info
# -------------------------------------
# name            str         jared
# nltk            module      <module 'nltk' from '/Use<...>ckages/nltk/__init__.py'>
# word_tokenize   function    <function word_tokenize at 0x1a1382e950>

# %%
string = input("Have something for me? ")
tokens = word_tokenize(string)
print(tokens)
print("There were", len(tokens), "tokens in your string." )
# Out:
# Have something for me? This is a string
# ['This', 'is', 'a', 'string']
# There were 4 tokens in your string.

# %%
def even_odd(x):
    if x % 2 == 0:
        print(x, "is even.")
    else:
        print(x, "is odd.")

# %%
even_odd(177)
# Out:
# 177 is odd.

# %%
even_odd(688)
# Out:
# 688 is even.

# %%
import nltk
from nltk import word_tokenize
string = input("Have something for me?\n")
tokens = word_tokenize(string)
tokens
print('You have', len(tokens), 'tokens')
# Out:
# Have something for me?
# This is a string of sorts. Good luck
# You have 9 tokens

# %%
sum = 0.0
data = input('Enter a number, or press enter to quit:')
while data != '':
    number = float(data)
    sums = number + data
# Out:
# Enter a number, or press enter to quit:

# %%
f = open('pg21190.txt')

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
whos
# Out:
# Variable   Type             Data/Info
# -------------------------------------
# data       str
# f          TextIOWrapper    <_io.TextIOWrapper name='<...>ode='r' encoding='UTF-8'>
# sum        float            0.0

# %%
for i in f:
    print(i)
# Out:
# ﻿Project Gutenberg's Expositions of Holy Scripture, by Alexander Maclaren
#
#
#
# This eBook is for the use of anyone anywhere at no cost and with
#
# almost no restrictions whatsoever.  You may copy it, give it away or
#
# re-use it under the terms of the Project Gutenberg License included
#
# with this eBook or online at www.gutenberg.net
#
#
#
#
#
# Title: Expositions of Holy Scripture
#
#        Second Corinthians, Galatians, and Philippians Chapters
#
#        I to End. Colossians, Thessalonians, and First Timothy.
#
#
#
# Author: Alexander Maclaren
#
#
#
# Release Date: April 19, 2007 [EBook #21190]
#
#
#
# Language: English
#
#
#
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK EXPOSITIONS OF HOLY SCRIPTURE ***
#
#
#
#
#
#
#
#
#
# Produced by Charles Franks and the Online Distributed
#
# Proofreading Team at http://www.pgdp.net
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _EXPOSITIONS OF HOLY SCRIPTURE_
#
#
#
# ALEXANDER MACLAREN, D. D., Litt. D.
#
#
#
# ...

# %%
f.close()

# %%
f
# Out:
# <_io.TextIOWrapper name='pg21190.txt' mode='r' encoding='UTF-8'>

# %%
f = open('pg21190.txt')
myfilecontents = f.read()
f.close()

# %%
f = open('pg21190.txt')
line1 = f.readline()
line2 = f.readline() # this DOESNT WORK LIKE IT CLAIMS IN THE TUTORIAL
print(line2)
f.close()

# %%
f = open('pg21190.txt')
mylines = f.readlines()
print(mylines[346:360]) # is there a way to fix the appearance below?
f.close()
# Out:
# ['together in one lustrous and all-comprehensive whole. So all the great\n', 'truths of the Gospel and all the blessed emotions of sonship which can\n', 'spring up in a human heart are intended to find their practical result\n', 'in holy and pure living. For this end God has spoken to us out of the\n', 'thick darkness; for this end Christ has come into our darkness; for this\n', 'end He has lived; for this end He died; for this end He rose again; for\n', 'this end He sends His Spirit and administers the providence of the\n', 'world. The purpose of all the Divine activity as regards us men is not\n', 'merely to make us happy, but to make us happy in order that we may be\n', 'good. He whom what he calls his religion has only saved from the wrath\n', 'of God and the fear of hell has not learned the alphabet of religion.\n', "Unless God's promises evoke men's goodness it will be of little avail\n", 'that they seem to quicken their hope. Joyful confidence in our sonship\n', 'is only warra
# ...

# %%
f = open('pg21190.txt')
mylines = f.readlines()
print(mylines[346:360])
print(len(mylines))
f.close()
# Out:
# []
# 0

# %%
def line_count(x):
    open(x)
    f = open(x)
    counter = 0
    for i in f:
        counter += 1
    print(counter)
line_count('pg21190.txt')
# Out:
# 0

# %%
f = open('pg21190.txt', 'w')
print("Is this the real life?", file=f)
print("I can't believe that I'm actually writing a commentary!", file=f)
print("okay, so maybe this doesn't really count", file=f)

# %%
line_count('pg21190.txt')
# Out:
# 0

# %%
whos
# Out:
# Variable         Type             Data/Info
# -------------------------------------------
# counter          int              23480
# data             str
# f                TextIOWrapper    <_io.TextIOWrapper name='<...>ode='r' encoding='UTF-8'>
# i                str              subscribe to our email ne<...> hear about new eBooks.\n
# line1            str              ﻿Project Gutenberg's Expo<...>, by Alexander Maclaren\n
# line2            str              \n
# line_count       function         <function line_count at 0x10ccac158>
# myfilecontents   str              ﻿Project Gutenberg's Expo<...> hear about new eBooks.\n
# mylines          list             n=0
# sum              float            0.0

# %%
f
# Out:
# <_io.TextIOWrapper name='pg21190.txt' mode='r' encoding='UTF-8'>

# %%
len(mylines)
# Out:
# 0

# %%
f = open('pg6.txt')
mylines = f.readlines()
print(mylines[346:360])
print(len(mylines))
f.close()
# Out:
# []
# 283

# %%
f = open('myoutfile.txt', 'w')
print("Is this the real life?", file=f)
print("I can't believe that I'm actually writing a commentary!", file=f)
print("okay, so maybe this doesn't really count", file=f)
f.close()

# %%
f = open('myoutfile.txt')

# %%
line_count('myoutfile.txt')
# Out:
# 3

# %%
def line_count(x):
    open(x)
    f = open(x)
    counter = 0
    for i in f:
        counter += 1
    print(counter)
    f = open(x)
    c_line = f.readlines()
    print('Verification:', len(c_line))
    f.close()
line_count('myoutfile.txt')
# Out:
# 0
# Verification: 0

# %%
line_count('pg6.txt')
# Out:
# 283
# Verification: 283

# %%
def line_count(x):
    open(x)
    f = open(x)
    counter = 0
    for i in f:
        counter += 1
    print(counter)
    f = open(x)
    c_line = f.readlines()
    return len(c_line) == counter
line_count('myoutfile.txt')
# Out:
# 3
# True

# %%
f = open('myoutfile.txt', 'w')
print('lets try our luck', file = f)
f.close()

# %%
line_count('myoutfile.txt')
# Out:
# 3
# Verification: 3
