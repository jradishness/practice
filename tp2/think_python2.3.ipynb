# %%
repeat_lyrics()
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")
def repeat_lyrics():
    print_lyrics()
    print_lyrics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f4a892574208> in <module>()
# ----> 1 repeat_lyrics()
#       2 def print_lyrics():
#       3     print("I'm a lumberjack, and I'm okay.")
#       4     print("I sleep all night and I work all day.")
#       5 def repeat_lyrics():
#
# NameError: name 'repeat_lyrics' is not defined

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")
    repeat_lyrics() # hehehe
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# ...

# %%
math.pow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4fc6e929196b> in <module>()
# ----> 1 math.pow()
#
# NameError: name 'math' is not defined

# %%
import math

# %%
math.pow(3, 3)
# Out:
# 27.0

# %%
def print_twice(arbitrary):
    print(arbitrary)
    print(arbitrary)

# %%
print_twice('hello')
# Out:
# hello
# hello

# %%
print_twice(math.pi)
# Out:
# 3.141592653589793
# 3.141592653589793

# %%
print_twice('spam ' * 4)
# Out:
# spam spam spam spam
# spam spam spam spam

# %%
print_twice(math.cos(math.pi))
# Out:
# -1.0
# -1.0

# %%
def right_justify(s):
    l = (len(s))
    x = 70 - l
    print(' ' * x, s)

# %% [raw]
# right_justify('hello')

# %%
def do_twice(f):
    f()
    f()

# %%
def print_spam():
    print('spam')

# %%
do_twice(print_spam)
# Out:
# spam
# spam

# %%
do_twice(math.cos(math.pi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-73ca39ce36af> in <module>()
# ----> 1 do_twice(math.cos(math.pi))
#
# NameError: name 'math' is not defined

# %%
import math

# %%
do_twice(math.cos(math.pi))
# Out:
# -1.0
# -1.0

# %%
def right_justify(s):
    print(" " * (70 - (len(s))), s)

# %%
right_justify("monty")
right_justify("python presents")
# Out:
#                                                                   monty
#                                                         python presents

# %%
def do_twice(f):
    f()
    f()
def print_spam():
    print('spam')
do_twice(print_spam)
# Out:
# spam
# spam

# %%
whos
# Out:
# Variable        Type        Data/Info
# -------------------------------------
# do_twice        function    <function do_twice at 0x10fe422f0>
# math            module      <module 'math' from '/Use<...>h.cpython-36m-darwin.so'>
# print_spam      function    <function print_spam at 0x10fe16598>
# right_justify   function    <function right_justify at 0x10fe16d90>

# %%
def do_twice(f, x, y):
    f(x, y)
    f(x, y)
def print_thrice(x, y):
    print(x * y)
do_twice(print_thrice, 'spam ', 16)
# Out:
# spam spam spam spam spam spam spam spam spam spam spam spam spam spam spam spam
# spam spam spam spam spam spam spam spam spam spam spam spam spam spam spam spam

# %%
def do_twice(f):
    f(x)
    f(x)
def print_twice(arbitrary):
    print(arbitrary)
    print(arbitrary)
do_twice(print_twice, 'spam')
# Out:
# spam
# spam
# spam
# spam

# %%
def do_four(h, g):
    do_twice(h, g)
    do_twice(h, g)

# %%
do_four(print, 'hope this works')
# Out:
# hope this works
# hope this works
# hope this works
# hope this works

# %%
do_four(print_twice, 'hello')
# Out:
# hello
# hello
# hello
# hello

# %%
do_four()

# %%
def repeat(f, a):
    f(a)
    print("These are the lyrics.")
repeat(repeat, 'poop')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-eec5247c7e8b> in <module>()
#       2     f(a)
#       3     print("These are the lyrics.")
# ----> 4 repeat(repeat, repeat)
#
# <ipython-input-87-eec5247c7e8b> in repeat(f, a)
#       1 def repeat(f, a):
# ----> 2     f(a)
#       3     print("These are the lyrics.")
#       4 repeat(repeat, repeat)
#
# TypeError: repeat() missing 1 required positional argument: 'a'

# %%
def do_twice(f):
    f()
    f()
def do_four(f):
    do_twice(f)
    do_twice(f)
def stripe():    
    print('|', ' ' * 13, '|', ' ' * 13, '|')
def row():
    print('+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ')
    do_four(stripe)
def grid():
    row()
    row()
    print('+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ')
grid()
# Out:
# +  -  -  -  -   +  -  -  -  -   +
# |               |               |
# |               |               |
# |               |               |
# |               |               |
# +  -  -  -  -   +  -  -  -  -   +
# |               |               |
# |               |               |
# |               |               |
# |               |               |
# +  -  -  -  -   +  -  -  -  -   +

# %%
def row():
    print('+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ', '-  ' * 4, '+')
    print('|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|')
    print('|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|')
    print('|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|')
    print('|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|', ' ' * 13, '|')
def grid():
    row()
    row()
    row()
    row()
    print('+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ', '-  ' * 4, '+ ', '-  ' * 4, '+')

grid()
# Out:
# +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +
# |               |               |               |               |
# |               |               |               |               |
# |               |               |               |               |
# |               |               |               |               |
# +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +
# |               |               |               |               |
# |               |               |               |               |
# |               |               |               |               |
# |               |               |               |               |
# +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +  -  -  -  -   +
# |               |               |               |               |
# |               |               |               |               |
# |               |               |               |               |
# ...

# %%
def do_twice(f):
    f()
    f()

# %%
def do_four(f):
    do_twice(f)
    do_twice(f)

# %%
def print_beam():
    print('+ - - - -', end=' ')

# %%
def print_post():
    print('|        ', end=' ')

# %%
def print_beams():
    do_twice(print_beam)
    print('+')

# %%
def print_posts():
    do_twice(print_post)
    print('|')

# %%
def print_row():
    print_beams()
    do_four(print_posts)

# %%
def print_grid():
    do_twice(print_row)
    print_beams()

# %%
print_grid()
# Out:
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +

# %%
def print_hi(q):
    for x in q:
        print(hi)

# %%
print_hi(9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-704b41188adf> in <module>()
# ----> 1 print_hi(9)
#
# <ipython-input-99-dd6e84a3ee57> in print_hi(q)
#       1 def print_hi(q):
# ----> 2     for x in q:
#       3         print(hi)
#
# TypeError: 'int' object is not iterable
